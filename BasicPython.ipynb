# %%
print("Hello")
# Out:
# Hello

# %%
print('Hell',end =',')
print('Hey')
# Out:
# Hell,Hey

# %%
print("apple","banana","apple",sep=',')
# Out:
# apple,banana,apple

# %%
Fruit = input("Enter fruit name:")
Color = input("Enter fruit color:")
print(f"The {Fruit} color is {Color}")
# Out:
# Enter fruit name: Apple
# Enter fruit color: red
# The Apple color is red

# %%
#Ass mulipule values to multi var
x,y,z=16,12,14
print(x)
print(y)
print(z)
#Ass single value to multi var
a=b=c = 18
print(a)
print(b)
print(c)
# Out:
# 16
# 12
# 14
# 18
# 18
# 18

# %%
#Datatypes
x = 10
y = "Hello"
z = True
a = 10.2
b = 3+2j
print(type(x))
print(type(y))
print(type(z))
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'float'>
# <class 'complex'>

# %%
#Escape char
print('she is ana sis.\nshe is very intel')
print('Name:\tVamshi')
print('Age :\t27')
# Out:
# she is ana sis.
# she is very intel
# Name:	Vamshi
# Age :	27

# %%
#Type conv
x = 10
y = float(x)
print(y)
A= True
B = float(A)
print(B)
# Out:
# 10.0
# 1.0

# %%
#Operations(Arth,Logic,Compare,Bitwise,Assign,membership,identify)
#Arth
A = 10
B = 20
print(A+B)
print(A-B)
print(A*B)
print(A/B)
print(A//B)
print(A%B)
#Logic return True or False
print(A>8 and B>18)
print(A>20 or B>30)
print(not(A>20 or B>30))
#Ass
A+=B
print(A)
#Mem
print('a'in'banana')
print('c' not in 'Red')
#identify
x = 10
y = 10
print(x is y)
print(x is not y)
# Out:
# 30
# -10
# 200
# 0.5
# 0
# 10
# True
# False
# True
# 30
# True
# True
# True
# False

# %%
#Slicing and indexing
X = 'Hello my dear frnd'
print(X[0])
print(X[1])
print(X[-1])
print(X[0:])
print(X[4:9])
print(X[::-1])
print(X[:5])
print(X[::2])
# Out:
# H
# e
# d
# Hello my dear frnd
# o my
# dnrf raed ym olleH
# Hello
# Hlom erfn

# %%
#Operations on String
A = 'My Self Vamshi'
print(len(A))
print(A.upper())
print(A.lower())
print(A.replace('V','B'))
print(A.find('S'))
print(A.swapcase())
print(A.title())
print(A.capitalize())
print(A.index("Self"))
B = 'How you doing'
print(A+','+B)
print(A*2)
X = 'Hey Hello Hola'
print(X.split(' '))
print(X.isalpha())
print(B.count('o'))
y = 'Hello123'
print(y.isalnum())
print(y.isupper())
print(y.islower())
Z = "1243"
print(Z.isdigit())
G = "***Hello***"
print(G.strip('*'))
# Out:
# 14
# MY SELF VAMSHI
# my self vamshi
# My Self Bamshi
# 3
# mY sELF vAMSHI
# My Self Vamshi
# My self vamshi
# 3
# My Self Vamshi,How you doing
# My Self VamshiMy Self Vamshi
# ['Hey', 'Hello', 'Hola']
# False
# 3
# True
# False
# False
# True
# Hello

# %%
#Data structures(#List,Tuple,Set,Dict)
#List - mutable
A = [10,20,30,40,50]
print(A)
print(type(A))
#Index and Slicing
print(A[0])
print(A[-1])
print(A[4])
print(A[::-1])
print(A[0:3])
print(A[2:4])
print(A[::2])
#Adding value to list
A.append(70)
print(A)
B = [60,90]
A.extend(B)
print(A)
A.insert(-1,80)
print(A)
#Removing values to list
A.remove(70)
print(A)
Y = A.pop(3)
print(A)
print(Y)
del A[1]
print(A)
A.clear()
print(A)
# Out:
# [10, 20, 30, 40, 50]
# <class 'list'>
# 10
# 50
# 50
# [50, 40, 30, 20, 10]
# [10, 20, 30]
# [30, 40]
# [10, 30, 50]
# [10, 20, 30, 40, 50, 70]
# [10, 20, 30, 40, 50, 70, 60, 90]
# [10, 20, 30, 40, 50, 70, 60, 80, 90]
# [10, 20, 30, 40, 50, 60, 80, 90]
# [10, 20, 30, 50, 60, 80, 90]
# 40
# [10, 30, 50, 60, 80, 90]
# []

# %%
#Other Operation
A = [10,40,20,90,30]
print(A)
A.sort()
print(A)
print(A*2)
print(max(A))
print(min(A))
print(sum(A))
B = [50,80]
print(A+B)
Char =['P','Y','T','H','O','N']
print(''.join(Char))
print(A.count(10))
C = A.copy()
print(C)
C = ['apple','banana','red']
print(C.index('apple'))
# Out:
# [10, 40, 20, 90, 30]
# [10, 20, 30, 40, 90]
# [10, 20, 30, 40, 90, 10, 20, 30, 40, 90]
# 90
# 10
# 190
# [10, 20, 30, 40, 90, 50, 80]
# PYTHON
# 1
# [10, 20, 30, 40, 90]
# 0

# %%
#Tuple - immutabe
A = (10,20,30)
print(A)
print(type(A))
nested_tuple = ((1,2),('a','b','c'))
Tup = ('apple',123,True,3.14,[1,2,3])
print(Tup[0])
print(Tup[-1])
print(Tup[2])
print(len(Tup))
print(max(A))
print(min(A))
print(sum(A))
Tup1 = ('Orange')
Tup2 = ('Apple')
New = Tup1+Tup2
print(New)
print(New*2)
#convert tuple to list
Z = (10,20,30,50)
print(type(Z))
Y = list(Z)
print(type(Y))
Y.append(40)
print(Y)
D = (1,2,3,4,5)
E,*F,G = D
print(E)
print(F)
print(G)
Tup[-1].append(50)
print(Tup)
# Out:
# (10, 20, 30)
# <class 'tuple'>
# apple
# [1, 2, 3]
# True
# 5
# 30
# 10
# 60
# OrangeApple
# OrangeAppleOrangeApple
# <class 'tuple'>
# <class 'list'>
# [10, 20, 30, 50, 40]
# 1
# [2, 3, 4]
# 5
# ('apple', 123, True, 3.14, [1, 2, 3, 50])

# %%
#Set - mutable not allow duplicate
A = {10,20,30,30}
print(A)
print(type(A))
A.add(50)
print(A)
A.remove(20)
print(A)
A.pop()
print(A)
A.discard(50)
print(A)
A.clear()
print(A)
#Set Operation
C = {10,20,30,40}
B = {50,20,50}
D = C|B
print(D)
E = C&B
print(E)
F = C-B
print(F)
G = C^B
print(G)
#Operation
print(len(C))
print(max(C))
print(min(C))
print(sum(C))
K = B.copy()
print(K)
a = {'apple','banana','cherry'}
b = {'Fig','Mango','apple'}
c = {'Gauva','Pinapple','banana'}
a.difference_update(b,c)
print(a)
# Out:
# {10, 20, 30}
# <class 'set'>
# {10, 20, 50, 30}
# {10, 50, 30}
# {50, 30}
# {30}
# set()
# {50, 20, 40, 10, 30}
# {20}
# {40, 10, 30}
# {40, 10, 50, 30}
# 4
# 40
# 10
# 100
# {50, 20}
# {'cherry'}

# %%
#Dict - Mutuable
MyDict = {'name':'Vamshi','age':29,'City':'New York'}
print(MyDict)
print(type(MyDict))
print(MyDict['name'])
print(len(MyDict))
stud = {'st1':{"name":"Vamshi","Age":26,"City":"Hyd"},
        'st2':{"name":"Sai","Age":28,"City":"CHN"},
        'st3':{"name":"Siva","Age":40,"City":"BNG"}}
Stud1 = stud.copy()
print("Name:",stud['st1']['name'])
print("Age:",stud['st1']['Age'])
print("City:",stud['st1']['City'])
MyDict.setdefault("Sex","Male")
print(MyDict)
MyDict["Region"]="South"
print(MyDict)
MyDict.update({'name':'siddhi'})
print(MyDict)
del MyDict['age']
print(MyDict)
MyDict.pop('name')
print(MyDict)
print(MyDict.keys())
print(MyDict.values())
print(MyDict.items())
MyDict.popitem()
print(MyDict)
MyDict.clear()
print(MyDict)
print(Stud1)
A = [1,2]
B = ['a','b']
C = zip(A,B)
print(dict(C))
C = [['a',1],['b',2],['c',3]]
print(dict(C))
# Out:
# {'name': 'Vamshi', 'age': 29, 'City': 'New York'}
# <class 'dict'>
# Vamshi
# 3
# Name: Vamshi
# Age: 26
# City: Hyd
# {'name': 'Vamshi', 'age': 29, 'City': 'New York', 'Sex': 'Male'}
# {'name': 'Vamshi', 'age': 29, 'City': 'New York', 'Sex': 'Male', 'Region': 'South'}
# {'name': 'siddhi', 'age': 29, 'City': 'New York', 'Sex': 'Male', 'Region': 'South'}
# {'name': 'siddhi', 'City': 'New York', 'Sex': 'Male', 'Region': 'South'}
# {'City': 'New York', 'Sex': 'Male', 'Region': 'South'}
# dict_keys(['City', 'Sex', 'Region'])
# dict_values(['New York', 'Male', 'South'])
# dict_items([('City', 'New York'), ('Sex', 'Male'), ('Region', 'South')])
# {'City': 'New York', 'Sex': 'Male'}
# {}
# {'st1': {'name': 'Vamshi', 'Age': 26, 'City': 'Hyd'}, 'st2': {'name': 'Sai', 'Age': 28, 'City': 'CHN'}, 'st3': {'name': 'Siva', 'Age': 40, 'City': 'BNG'}}
# {1: 'a', 2: 'b'}
# {'a': 1, 'b': 2, 'c': 3}
